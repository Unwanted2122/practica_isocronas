# %%
import geopandas as gp
import pandas as pd
from shapely.geometry import Polygon
from routingpy.routers import MapboxOSRM
import numpy as np

mb = MapboxOSRM(api_key = "pk.eyJ1IjoiY2FybG9hZDEzMTciLCJhIjoiY200aXAzaG9lMDRrcDJyb3BlMWs5bjZxbyJ9.cMOjch9URfW3X133K7MDQw")

# %%
dallas_libraries = gp.read_file("https://egis.dallascityhall.com/resources/Downloads/ShpZip/Library/Libraries.zip")

dallas_libraries.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3d3a73f9fc04ebf4ce9c52825cf52eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3d3a73f9fc04ebf4ce9c52825cf52eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3d3a73f9fc04ebf4ce9c52825cf52eb = L.map(
#                 &quot;map_a3d3a73f9fc04ebf4ce9c52825cf52eb&quot;,
#                 {
#                     center: [32.826917316756465, -96.78353058917139],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a3d3a73f9fc04ebf4ce9c52825cf52eb);
#
#
#
#
#
#             var tile_layer_c8e41635322e009f101f40f10582cc82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c8e41635322e009f101f40f10582cc82.addTo(map_a3d3a73f9fc04ebf4ce9c52825cf52eb);
#
#
#             map_a3d3a73f9fc04ebf4ce9c52825cf52eb.fitBounds(
#                 [[32.650592440484445, -96.9660369492034], [33.00324219302849, -96.6010242291394]],
#                 {}
#             );
#
#
#         function geo_json_aad857329d0101b6c7ef4d026d00a7b9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_aad857329d0101b6c7ef4d026d00a7b9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_aad857329d0101b6c7ef4d026d00a7b9_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_aad857329d0101b6c7ef4d026d00a7b9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_aad857329d0101b6c7ef4d026d00a7b9_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_aad857329d0101b6c7ef4d026d00a7b9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_aad857329d0101b6c7ef4d026d00a7b9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_aad857329d0101b6c7ef4d026d00a7b9 = L.geoJson(null, {
#                 onEachFeature: geo_json_aad857329d0101b6c7ef4d026d00a7b9_onEachFeature,
#
#                 style: geo_json_aad857329d0101b6c7ef4d026d00a7b9_styler,
#                 pointToLayer: geo_json_aad857329d0101b6c7ef4d026d00a7b9_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_aad857329d0101b6c7ef4d026d00a7b9_add (data) {
#             geo_json_aad857329d0101b6c7ef4d026d00a7b9
#                 .addData(data);
#         }
#             geo_json_aad857329d0101b6c7ef4d026d00a7b9_add({&quot;bbox&quot;: [-96.9660369492034, 32.650592440484445, -96.6010242291394, 33.00324219302849], &quot;features&quot;: [{&quot;bbox&quot;: [-96.90946820891253, 32.75914885683109, -96.90946820891253, 32.75914885683109], &quot;geometry&quot;: {&quot;coordinates&quot;: [-96.90946820891253, 32.75914885683109], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;1302 N Justin Ave&quot;, &quot;BranchClas&quot;: &quot;Branch&quot;, &quot;Library&quot;: &quot;Arcadia Park&quot;, &quot;Telephone&quot;: &quot;214-670-6446&quot;, &quot;Url&quot;: &quot;http://www.dallaslibrary2.org/branch/arcadia.php&quot;},

# %%
def mb_isochrone(gdf, time = [5, 10, 15], profile = "driving"):

    # Grab X and Y values in 4326
    gdf['LON_VALUE'] = gdf.to_crs(4326).geometry.x
    gdf['LAT_VALUE'] = gdf.to_crs(4326).geometry.y

    coordinates = gdf[['LON_VALUE', 'LAT_VALUE']].values.tolist()

    # Build a list of shapes
    isochrone_shapes = []

    if type(time) is not list:
        time = [time]

    # Use minutes as input, but the API requires seconds
    time_seconds = [60 * x for x in time]

    # Given the way that routingpy works, we need to iterate through the list of 
    # coordinate pairs, then iterate through the object returned and extract the 
    # isochrone geometries.  
    for c in coordinates:
        iso_request = mb.isochrones(locations = c, profile = profile,
                                    intervals = time_seconds, polygons = "true")

        for i in iso_request:
            iso_geom = Polygon(i.geometry[0])
            isochrone_shapes.append(iso_geom)

    # Here, we re-build the dataset but with isochrone geometries
    df_values = gdf.drop(columns = ['geometry', 'LON_VALUE', 'LAT_VALUE'])

    time_col = time * len(df_values)

    # We'll need to repeat the dataframe to account for multiple time intervals
    df_values_rep = pd.DataFrame(np.repeat(df_values.values, len(time_seconds), axis = 0))
    df_values_rep.columns = df_values.columns

    isochrone_gdf = gp.GeoDataFrame(
        data = df_values_rep,
        geometry = isochrone_shapes,
        crs = 4326
    )

    isochrone_gdf['time'] = time_col

    # We are sorting the dataframe in descending order of time to improve visualization
    # (the smallest isochrones should go on top, which means they are plotted last)
    isochrone_gdf = isochrone_gdf.sort_values('time', ascending = False)

    return(isochrone_gdf)

# %%
dallas_libraries.head()
# Out:
#                          Library                   Address     Telephone  \
# 0                   Arcadia Park         1302 N Justin Ave  214-670-6446
# 1                   Audelia Road          10045 Audelia Rd  214-670-1350
# 2                   Bachman Lake       9480 Webb Chapel Rd  214-670-6376
# 3  Bookmarks at NorthPark Center  8687 North Central Expwy  214-671-1381
# 4                    Dallas West       2332 Singleton Blvd  214-670-6445
#
#                                                  Url BranchClas  \
# 0   http://www.dallaslibrary2.org/branch/arcadia.php     Branch
# 1   http://www.dallaslibrary2.org/branch/audelia.php     Branch
# 2   http://www.dallaslibrary2.org/branch/bachman.php     Branch
# 3  http://www.dallaslibrary2.org/branch/bookmarks...     Branch
# 4  http://www.dallaslibrary2.org/branch/dallaswes...     Branch
#
#                           geometry  LON_VALUE  LAT_VALUE
# 0  POINT (2457410.114 6962825.079) -96.909468  32.759149
# 1  POINT (2515388.236 7009805.942) -96.718295  32.885712
# 2  POINT (2472278.638 7000779.757) -96.859177  32.862835
# 3  POINT (2498263.282 7003408.784) -96.774418  32.868916
# 4  POINT (2472480.223 6970036.566) -96.860083  32.778332

# %%
library_isos = mb_isochrone(dallas_libraries, time = 5, 
                            profile = "driving-traffic")

library_isos.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ea5068894d9a90b6a0684ebe8bb2ffa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ea5068894d9a90b6a0684ebe8bb2ffa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ea5068894d9a90b6a0684ebe8bb2ffa = L.map(
#                 &quot;map_0ea5068894d9a90b6a0684ebe8bb2ffa&quot;,
#                 {
#                     center: [32.826812000000004, -96.782667],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0ea5068894d9a90b6a0684ebe8bb2ffa);
#
#
#
#
#
#             var tile_layer_1e5699fa1c52808c09e14830ba7de730 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e5699fa1c52808c09e14830ba7de730.addTo(map_0ea5068894d9a90b6a0684ebe8bb2ffa);
#
#
#             map_0ea5068894d9a90b6a0684ebe8bb2ffa.fitBounds(
#                 [[32.627891, -96.99131], [33.025733, -96.574024]],
#                 {}
#             );
#
#
#         function geo_json_0b6c50ee80ba006c9a44c85f1810e662_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0b6c50ee80ba006c9a44c85f1810e662_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0b6c50ee80ba006c9a44c85f1810e662_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0b6c50ee80ba006c9a44c85f1810e662_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0b6c50ee80ba006c9a44c85f1810e662_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_0b6c50ee80ba006c9a44c85f1810e662.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0b6c50ee80ba006c9a44c85f1810e662_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0b6c50ee80ba006c9a44c85f1810e662 = L.geoJson(null, {
#                 onEachFeature: geo_json_0b6c50ee80ba006c9a44c85f1810e662_onEachFeature,
#
#                 style: geo_json_0b6c50ee80ba006c9a44c85f1810e662_styler,
#                 pointToLayer: geo_json_0b6c50ee80ba006c9a44c85f1810e662_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_0b6c50ee80ba006c9a44c85f1810e662_add (data) {
#             geo_json_0b6c50ee80ba006c9a44c85f1810e662
#                 .addData(data);
#         }
#             geo_json_0b6c50ee80ba006c9a44c85f1810e662_add({&quot;bbox&quot;: [-96.99131, 32.627891, -96.574024, 33.025733], &quot;features&quot;: [{&quot;bbox&quot;: [-96.918852, 32.749108, -96.908652, 32.76013], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-96.909468, 32.759982], [-96.912449, 32.76013], [-96.913727, 32.759408], [-96.913957, 32.758149], [-96.913468, 32.758062], [-96.913051, 32.757149], [-96.913468, 32.756755], [-96.914468, 32.758027], [-96.915468, 32.757645], [-96.915739, 32.757878], [-96.916468, 32.75974], [-96.916846, 32.758527], [-96.918852, 32.758149], [-96.917418, 32.757199], [-96.916747, 32.75587], [-96.915164, 32.755453], [-96.914468, 32.754568], [-96.913755, 32.755435], [-96.913208, 32.755409], [-96.91309, 32.752771], [-96.914072, 3

# %%
library_isos.head()
# Out:
#                          Library                   Address     Telephone  \
# 0                   Arcadia Park         1302 N Justin Ave  214-670-6446
# 1                   Audelia Road          10045 Audelia Rd  214-670-1350
# 2                   Bachman Lake       9480 Webb Chapel Rd  214-670-6376
# 3  Bookmarks at NorthPark Center  8687 North Central Expwy  214-671-1381
# 4                    Dallas West       2332 Singleton Blvd  214-670-6445
#
#                                                  Url BranchClas  \
# 0   http://www.dallaslibrary2.org/branch/arcadia.php     Branch
# 1   http://www.dallaslibrary2.org/branch/audelia.php     Branch
# 2   http://www.dallaslibrary2.org/branch/bachman.php     Branch
# 3  http://www.dallaslibrary2.org/branch/bookmarks...     Branch
# 4  http://www.dallaslibrary2.org/branch/dallaswes...     Branch
#
#                                             geometry  time
# 0  POLYGON ((-96.90947 32.75998, -96.91245 32.760...     5
# 1  POLYGON ((-96.7173 32.90172, -96.71957 32.9017...     5
# 2  POLYGON ((-96.86618 32.88605, -96.86845 32.885...     5
# 3  POLYGON ((-96.76942 32.89364, -96.76962 32.888...     5
# 4  POLYGON ((-96.85208 32.80684, -96.85339 32.805...     5

# %%
library_isos.dtypes
# Out:
# Library         object
# Address         object
# Telephone       object
# Url             object
# BranchClas      object
# geometry      geometry
# time             int64
# dtype: object

# %%
dickies = gp.tools.geocode("1911 Montgomery St, Fort Worth, TX 76107")

dickies_isos = mb_isochrone(dickies, time = [5, 10, 15], profile = "driving-traffic")

dickies_isos.explore(column = "time")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2de389ba0a4634a1700e70b096bb6fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2de389ba0a4634a1700e70b096bb6fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2de389ba0a4634a1700e70b096bb6fa = L.map(
#                 &quot;map_e2de389ba0a4634a1700e70b096bb6fa&quot;,
#                 {
#                     center: [32.7240645, -97.374118],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e2de389ba0a4634a1700e70b096bb6fa);
#
#
#
#
#
#             var tile_layer_21a6efd9b09ffa73bd1ad4e3444e1203 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21a6efd9b09ffa73bd1ad4e3444e1203.addTo(map_e2de389ba0a4634a1700e70b096bb6fa);
#
#
#             map_e2de389ba0a4634a1700e70b096bb6fa.fitBounds(
#                 [[32.589032, -97.569887], [32.859097, -97.178349]],
#                 {}
#             );
#
#
#         function geo_json_505cabc7a1e88548f152b3fee50f1c96_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#21908d&quot;, &quot;fillColor&quot;: &quot;#21908d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_505cabc7a1e88548f152b3fee50f1c96_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_505cabc7a1e88548f152b3fee50f1c96_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_505cabc7a1e88548f152b3fee50f1c96_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_505cabc7a1e88548f152b3fee50f1c96_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_505cabc7a1e88548f152b3fee50f1c96.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_505cabc7a1e88548f152b3fee50f1c96_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_505cabc7a1e88548f152b3fee50f1c96 = L.geoJson(null, {
#                 onEachFeature: geo_json_505cabc7a1e88548f152b3fee50f1c96_onEachFeature,
#
#                 style: geo_json_505cabc7a1e88548f152b3fee50f1c96_styler,
#                 pointToLayer: geo_json_505cabc7a1e88548f152b3fee50f1c96_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_505cabc7a1e88548f152b3fee50f1c96_add (data) {
#             geo_json_505cabc7a1e88548f152b3fee50f1c96
#                 .addData(data);
#         }
#             geo_json_505cabc7a1e88548f152b3fee50f1c96_add({&quot;bbox&quot;: [-97.569887, 32.589032, -97.178349, 32.859097], &quot;features&quot;: [{&quot;bbox&quot;: [-97.569887, 32
